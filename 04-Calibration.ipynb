# %%
from sarpy.load import sar_load
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# load image

# %%
path = "/home/simon/Desktop/dev_sarpy/test_data/S1A_IW_GRDH_1SDV_20181009T171427_20181009T171452_024062_02A131_E887.SAFE"
img = sar_load(path,location=(43.20203134094203, 9.326176488289917),size=(4800,4000))

# %% [markdown]
# VV

# %%
img.simple_plot(0)

# %% [markdown]
# VH

# %%
img.simple_plot(1)

# %% [markdown]
# ### Calibration

# %%
img_cal = img.calibrate(mode='gamma',tiles=3)

# %% [markdown]
# VV

# %%
img_cal.simple_plot(0)

# %% [markdown]
# VH

# %%
img_cal.simple_plot(1)
