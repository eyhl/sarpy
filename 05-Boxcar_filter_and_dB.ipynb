# %%
from sarpy.load import sar_load

# %%
path = "/home/simon/Desktop/dev_sarpy/test_data/S1A_IW_GRDH_1SDV_20181009T171427_20181009T171452_024062_02A131_E887.SAFE"
img = sar_load(path,['VV'],location=(43.20203134094203, 9.326176488289917),size=(4800,4000))
img =img.calibrate()

# %% [markdown]
# ### Plot gamma VV

# %%
img.simple_plot()

# %% [markdown]
# ### Boxcar Filter and plot

# %%
img = img.boxcar(11)
img.simple_plot(0,0.99)

# %% [markdown]
# ### Convert to dB

# %%
img = img.to_db()
img.simple_plot(0,0.99)
